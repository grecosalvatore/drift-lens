512077331543], 'mean': 0.07961955070495605, 'std': 0.0031767620920311363}, 'KS': {'running_time_list': [1.864326000213623, 1.8571820259094238, 1.8576099872589111, 1.8585290908813477, 1.8567888736724854], 'mean': 1.8588871955871582, 'std': 0.002780311289995558}, 'MMD': {'running_time_list': [14.191308975219727, 14.155163288116455, 14.278541088104248, 14.236337900161743, 14.204845190048218], 'mean': 14.213239288330078, 'std': 0.04176623574657416}, 'LSDD': {'running_time_list': [0.6383399963378906, 0.5734858512878418, 0.5665040016174316, 0.5697338581085205, 0.5659699440002441], 'mean': 0.5828067302703858, 'std': 0.02789616011256843}, 'CVM': {'running_time_list': [1.3829822540283203, 1.3813800811767578, 1.3839101791381836, 1.3840610980987549, 1.382615089416504], 'mean': 1.3829897403717042, 'std': 0.000972258917119768}}, 2500: {'DriftLens': {'running_time_list': [0.07700300216674805, 0.08178210258483887, 0.08191895484924316, 0.08942699432373047, 0.0870821475982666], 'mean': 0.08344264030456543, 'std': 0.004372789695355317}, 'KS': {'running_time_list': [2.3420841693878174, 2.3326759338378906, 2.3329508304595947, 2.3326969146728516, 2.332490921020508], 'mean': 2.3345797538757322, 'std': 0.0037550627310638063}, 'MMD': {'running_time_list': [14.399922847747803, 14.442726135253906, 14.548295974731445, 14.531132936477661, 14.189714908599854], 'mean': 14.422358560562134, 'std': 0.12863387209450225}, 'LSDD': {'running_time_list': [0.6091639995574951, 0.5948848724365234, 0.586029052734375, 0.6003260612487793, 0.6016459465026855], 'mean': 0.5984099864959717, 'std': 0.0076877243250779905}, 'CVM': {'running_time_list': [1.7267711162567139, 1.7269701957702637, 1.7268548011779785, 1.7272028923034668, 1.7258026599884033], 'mean': 1.7267203330993652, 'std': 0.0004812648484130948}}}

# %%
def plot_dual_drift_detector_performance_improved(data1, data2, data3, filename):
    import matplotlib.pyplot as plt
    import numpy as np

    # Prepare plot with two subplots side-by-side
    fig, axs = plt.subplots(1, 3, figsize=(20, 6))
    
    # Define line styles, markers, and colors for better differentiation
    custom_dash = (0, (3, 10, 1, 10))  # Custom dash pattern
    line_styles = ['--', '-', ':', '-.']  # The last one is a custom dash pattern
    markers = ['d', 'o', 's', 'P']
    colors = ['tab:green', 'tab:blue', 'tab:purple', 'tab:red']
    
    # Extract unique techniques, ensuring "MMD" is excluded
    techniques = list(set(list(data1[next(iter(data1))].keys()) + list(data2[next(iter(data2))].keys()) + list(data3[next(iter(data3))].keys())))
    techniques = [tech for tech in techniques if tech != "MMD"]  # Exclude "MMD"
    
    # Define your preferred order for the labels
    preferred_order = ["CVM", "DriftLens", "LSDD", "KS"]
    
    # Ensure techniques are ordered as per preferred_order
    techniques = sorted(techniques, key=lambda x: preferred_order.index(x) if x in preferred_order else len(preferred_order))

    
     # Plot for the first dataset
    for idx, technique in enumerate(techniques):
        window_sizes = sorted(data1.keys())
        means = [data1[ws][technique]['mean'] for ws in window_sizes if technique in data1[ws]]
        stds = [data1[ws][technique]['std'] for ws in window_sizes if technique in data1[ws]]
        axs[0].plot(window_sizes, means, line_styles[idx % len(line_styles)], marker=markers[idx], markersize=10, color=colors[idx], label=technique, linewidth=2.5, alpha=0.8)
        axs[0].fill_between(window_sizes, np.subtract(means, stds), np.add(means, stds), color=colors[idx], alpha=0.2)

    axs[0].set_xlabel('Reference Window Size', fontsize=16, labelpad=10)
    axs[0].set_title('a) Running Time for Reference Window Size', fontsize=18, pad=20)
    axs[0].set_ylabel('Mean Running Time (s)', fontsize=16)
    axs[0].set_xticks(sorted(data1.keys()))
    axs[0].grid(True)

    

    # Plot for the first dataset
    for idx, technique in enumerate(techniques):
        #if technique != "MMD":
        window_sizes = sorted(data2.keys())
        means = [data2[ws][technique]['mean'] for ws in window_sizes if technique in data2[ws]]
        stds = [data2[ws][technique]['std'] for ws in window_sizes if technique in data2[ws]]
        axs[1].plot(window_sizes, means, line_styles[idx % len(line_styles)], marker=markers[idx], markersize=10, color=colors[idx], label=technique, linewidth=2.5, alpha=0.8)
        axs[1].fill_between(window_sizes, np.subtract(means, stds), np.add(means, stds), color=colors[idx], alpha=0.2)
    
    axs[1].set_xlabel('Datastream Window Size', fontsize=16, labelpad=10)
    axs[1].set_title('b) Running Time for Datastream Window Size', fontsize=18, pad=20)
    axs[1].set_xticks(sorted(data2.keys()))
    axs[1].grid(True)

    
    # Show y-ticks on the right plot
    axs[1].tick_params(labelleft=True)

    
    # Plot for the third dataset
    for idx, technique in enumerate(techniques):
        window_sizes = sorted(data3.keys())
        means = [data3[ws][technique]['mean'] for ws in window_sizes if technique in data3[ws]]
        stds = [data3[ws][technique]['std'] for ws in window_sizes if technique in data3[ws]]
        axs[2].plot(window_sizes, means, line_styles[idx % len(line_styles)], marker=markers[idx], markersize=10, color=colors[idx], label=technique, linewidth=2.5, alpha=0.8)
        axs[2].fill_between(window_sizes, np.subtract(means, stds), np.add(means, stds), color=colors[idx], alpha=0.2)

    axs[2].set_xlabel('Embedding dimensionality', fontsize=16, labelpad=10)
    axs[2].set_title('c) Running Time for Embdding Dimensionality', fontsize=18, pad=20)
    axs[2].set_xticks(sorted(data3.keys()))
    axs[2].grid(True)

    # Show y-ticks on the right plot
    axs[2].tick_params(labelleft=True)
    
    # Set grid and spines
    for ax in axs:
        ax.grid(True, which='major', linestyle='--', linewidth='0.5', color='grey', alpha=0.7)
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.spines['bottom'].set_visible(True)
        ax.spines['left'].set_visible(True)
        ax.tick_params(axis='both', which='major', labelsize=14)

    # After plotting, when handling legends:
    # Extract handles and labels
    handles, labels = axs[0].get_legend_handles_labels()
    
    # Sort handles and labels according to the preferred order
    labels_handles = sorted(zip(labels, handles), key=lambda lh: preferred_order.index(lh[0]) if lh[0] in preferred_order else len(preferred_order))
    sorted_labels, sorted_handles = zip(*labels_handles)

    
    fig.legend(handles, labels, loc='upper center', ncol=len(techniques), bbox_to_anchor=(0.5, -0.01), fontsize=16)

    # Adjust tight_layout to make space for the legend at the bottom
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    
    #plt.show()
    plt.savefig(f'{filename}.pdf', format='pdf', bbox_inches='tight')

# %%
plot_dual_drift_detector_performance_improved(data1, data2, data3, filename="running-time-comparison-no-MMD")
