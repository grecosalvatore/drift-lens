_list': [1.3757100105285645, 0.7506320476531982, 0.7346742153167725], 'mean': 0.9536720911661783, 'std': 0.29849697612987447}, 'CVM': {'running_time_list': [0.5484559535980225, 0.5377211570739746, 0.5322000980377197], 'mean': 0.5394590695699056, 'std': 0.006749245137148852}}, 1000: {'DriftLens': {'running_time_list': [0.12696075439453125, 0.07807302474975586, 0.07636499404907227], 'mean': 0.09379959106445312, 'std': 0.023458849179953507}, 'KS': {'running_time_list': [1.414048194885254, 0.979637861251831, 0.9498388767242432], 'mean': 1.1145083109537761, 'std': 0.21215576261948244}, 'MMD': {'running_time_list': [18.534478902816772, 17.446487188339233, 15.124542236328125], 'mean': 17.03516944249471, 'std': 1.4221588597154895}, 'LSDD': {'running_time_list': [0.9830179214477539, 0.6471900939941406, 0.740790843963623], 'mean': 0.7903329531351725, 'std': 0.14150594300576863}, 'CVM': {'running_time_list': [0.7277069091796875, 0.6987221240997314, 0.7280471324920654], 'mean': 0.7181587219238281, 'std': 0.013744451952389885}}, 1250: {'DriftLens': {'running_time_list': [0.09112191200256348, 0.07434391975402832, 0.07029199600219727], 'mean': 0.07858594258626302, 'std': 0.009017295175660252}, 'KS': {'running_time_list': [1.5202350616455078, 1.183518886566162, 1.765075922012329], 'mean': 1.489609956741333, 'std': 0.23840521408871265}, 'MMD': {'running_time_list': [15.944211959838867, 17.566838026046753, 20.832557201385498], 'mean': 18.114535729090374, 'std': 2.0328894674948663}, 'LSDD': {'running_time_list': [0.737767219543457, 1.6538827419281006, 1.542785882949829], 'mean': 1.311478614807129, 'std': 0.40820272889031606}, 'CVM': {'running_time_list': [0.875586986541748, 0.9383749961853027, 0.9173250198364258], 'mean': 0.9104290008544922, 'std': 0.026092781212424386}}, 1500: {'DriftLens': {'running_time_list': [0.16520977020263672, 0.08957505226135254, 0.0727241039276123], 'mean': 0.10916964213053386, 'std': 0.04021907160116839}, 'KS': {'running_time_list': [2.0673770904541016, 1.4582362174987793, 1.490727186203003], 'mean': 1.6721134980519612, 'std': 0.27980814423555617}, 'MMD': {'running_time_list': [20.44904088973999, 23.791123867034912, 19.524192094802856], 'mean': 21.254785617192585, 'std': 1.8327747836880361}, 'LSDD': {'running_time_list': [1.4042258262634277, 1.7511889934539795, 1.1574881076812744], 'mean': 1.4376343091328938, 'std': 0.24352587882680723}, 'CVM': {'running_time_list': [1.0988891124725342, 1.1137700080871582, 1.1478760242462158], 'mean': 1.1201783816019695, 'std': 0.02050576861291504}}}

# %%
def plot_dual_drift_detector_performance_improved(data1, data2, data3, filename):
    import matplotlib.pyplot as plt
    import numpy as np

    # Prepare plot with two subplots side-by-side
    fig, axs = plt.subplots(1, 3, figsize=(20, 6))
    
    # Define your line styles
    custom_dash = (0, (3, 10, 1, 10))  # Custom dash pattern
    line_styles = ['--', '-', '-', ':', '-.']  # The last one is a custom dash pattern


    # Define markers and colors for better differentiation
    markers = ['o', 's', 'o', 'd', 'P']
    colors = ['tab:green', 'tab:red', 'tab:purple', 'tab:orange', 'tab:blue']
    techniques = list(set(list(data1[next(iter(data1))].keys()) + list(data2[next(iter(data2))].keys())))
    
     # Plot for the first dataset
    for idx, technique in enumerate(techniques):
        window_sizes = sorted(data2.keys())
        means = [data2[ws][technique]['mean'] for ws in window_sizes if technique in data2[ws]]
        stds = [data2[ws][technique]['std'] for ws in window_sizes if technique in data2[ws]]
        axs[0].plot(window_sizes, means, line_styles[idx % len(line_styles)], marker=markers[idx], markersize=10, color=colors[idx], label=technique, linewidth=2.5, alpha=0.8)
        axs[0].fill_between(window_sizes, np.subtract(means, stds), np.add(means, stds), color=colors[idx], alpha=0.2)

    axs[0].set_xlabel('Datastream Window Size', fontsize=16, labelpad=10)
    axs[0].set_title('b) Running Time for Datastream Window Size', fontsize=18, pad=20)
    axs[0].set_ylabel('Mean Running Time (s)', fontsize=16)
    axs[0].set_xticks(sorted(data2.keys()))
    axs[0].grid(True)

    

    # Plot for the first dataset
    for idx, technique in enumerate(techniques):
        if technique != "MMD":
            window_sizes = sorted(data1.keys())
            means = [data1[ws][technique]['mean'] for ws in window_sizes if technique in data1[ws]]
            stds = [data1[ws][technique]['std'] for ws in window_sizes if technique in data1[ws]]
            axs[1].plot(window_sizes, means, line_styles[idx % len(line_styles)], marker=markers[idx], markersize=10, color=colors[idx], label=technique, linewidth=2.5, alpha=0.8)
            axs[1].fill_between(window_sizes, np.subtract(means, stds), np.add(means, stds), color=colors[idx], alpha=0.2)

    axs[1].set_xlabel('Reference Window Size', fontsize=16, labelpad=10)
    axs[1].set_title('a) Running Time for Reference Window Size', fontsize=18, pad=20)
    axs[1].set_xticks(sorted(data1.keys()))
    axs[1].grid(True)

    
    # Show y-ticks on the right plot
    axs[1].tick_params(labelleft=True)

    
    # Plot for the third dataset
    for idx, technique in enumerate(techniques):
        window_sizes = sorted(data3.keys())
        means = [data3[ws][technique]['mean'] for ws in window_sizes if technique in data3[ws]]
        stds = [data3[ws][technique]['std'] for ws in window_sizes if technique in data3[ws]]
        axs[2].plot(window_sizes, means, line_styles[idx % len(line_styles)], marker=markers[idx], markersize=10, color=colors[idx], label=technique, linewidth=2.5, alpha=0.8)
        axs[2].fill_between(window_sizes, np.subtract(means, stds), np.add(means, stds), color=colors[idx], alpha=0.2)

    axs[2].set_xlabel('Embedding dimensionality', fontsize=16, labelpad=10)
    axs[2].set_title('c) Running Time for Embdding Dimensionality', fontsize=18, pad=20)
    axs[2].set_xticks(sorted(data3.keys()))
    axs[2].grid(True)

    # Show y-ticks on the right plot
    axs[2].tick_params(labelleft=True)
    
    # Set grid and spines
    for ax in axs:
        ax.grid(True, which='major', linestyle='--', linewidth='0.5', color='grey', alpha=0.7)
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.spines['bottom'].set_visible(True)
        ax.spines['left'].set_visible(True)
        ax.tick_params(axis='both', which='major', labelsize=14)

    # Configure legend
    handles, labels = axs[0].get_legend_handles_labels()
    #fig.legend(handles, labels, loc='upper center', ncol=len(techniques), bbox_to_anchor=(0.5, 1.05), fontsize=16)

    #plt.tight_layout(rect=[0, 0, 1, 0.95])
    
    fig.legend(handles, labels, loc='upper center', ncol=len(techniques), bbox_to_anchor=(0.5, -0.01), fontsize=16)

    # Adjust tight_layout to make space for the legend at the bottom
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    
    #plt.show()
    plt.savefig(f'{filename}.pdf', format='pdf', bbox_inches='tight')

# %%
plot_dual_drift_detector_performance_improved(data1, data2, data3, filename="running-time-comparison")
